# %%
import pandas as pd
import numpy as np

# %%
healthData = pd.read_csv("data/Health_Nutrition_and_Population.csv")
worldDevelopmentData = pd.read_csv("data/World_Development_Indicators.csv")

# %%
healthData.head()
# Out:
#                                          Series Name  Series Code  \
# 0  Adolescent fertility rate (births per 1,000 wo...  SP.ADO.TFRT
# 1  Adolescent fertility rate (births per 1,000 wo...  SP.ADO.TFRT
# 2  Adolescent fertility rate (births per 1,000 wo...  SP.ADO.TFRT
# 3  Adolescent fertility rate (births per 1,000 wo...  SP.ADO.TFRT
# 4  Adolescent fertility rate (births per 1,000 wo...  SP.ADO.TFRT
#
#      Country Name Country Code 2016 [YR2016] 2017 [YR2017] 2018 [YR2018]  \
# 0     Afghanistan          AFG        75.325        68.957        65.141
# 1         Albania          ALB       19.8596        19.642       19.5724
# 2         Algeria          DZA        10.368        10.071        9.8338
# 3  American Samoa          ASM            ..            ..            ..
# 4         Andorra          AND            ..            ..            ..
#
#   2019 [YR2019] 2020 [YR2020]
# 0            ..            ..
# 1            ..            ..
# 2            ..            ..
# ...

# %%
worldDevelopmentData.head()
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
#
#                                          Series Name        Series Code  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 1            Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 2  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 3  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 4  Account ownership at a financial institution o...     FX.OWN.TOTL.ZS
#
#       2016 [YR2016]     2017 [YR2017]     2018 [YR2018] 2019 [YR2019]  \
# 0             32.44                ..                ..            ..
# 1              97.7              97.7  98.7132034301758            ..
# 2  97.0993597954095  97.0919732441472  98.2728721849277            ..
# 3              99.5              99.5               100            ..
# ...

# %%
healthData.columns = ['Metrics', 'Metrics_Code', 'Country_Name', 'Country_Code', '2016', '2017', '2018', '2019', '2020']

# %%
worldDevelopmentData.columns = ['Country_Name', 'Country_Code', 'Metrics', 'Metrics_Code', '2016', '2017', '2018', '2019', '2020']

# %%
worldDevelopmentData = worldDevelopmentData.iloc[:-5]
healthData = healthData[:-5]

# %%
healthData = healthData.replace('..', -1)

# %%
healthData['2016'] = healthData['2016'].apply(pd.to_numeric)
healthData['2017'] = healthData['2017'].apply(pd.to_numeric)
healthData['2018'] = healthData['2018'].apply(pd.to_numeric)
healthData['2019'] = healthData['2019'].apply(pd.to_numeric)
healthData['2020'] = healthData['2020'].apply(pd.to_numeric)

# %%
df_pivot = healthData.pivot_table(values=['2016', '2017', '2018', '2019', '2020'], index=['Country_Name'], columns=['Metrics'])

# %%
years = ['2019', '2018', '2017', '2016']

for year in years:
    df = df.fillna(df_pivot[year])

# %%
df
# Out:
# Metrics                ARI treatment (% of children under 5 taken to a health provider)  \
# Country_Name
# Afghanistan                                                         67.7
# Albania                                                             82.4
# Algeria                                                              NaN
# American Samoa                                                       NaN
# Andorra                                                              NaN
# ...                                                                  ...
# Virgin Islands (U.S.)                                                NaN
# West Bank and Gaza                                                   NaN
# Yemen, Rep.                                                          NaN
# Zambia                                                              76.0
# Zimbabwe                                                            48.0
#
# ...

# %%
df_pivot['2016']
# Out:
# Metrics                AIDS estimated deaths (UNAIDS estimates)  \
# Country_Name
# Afghanistan                                               500.0
# Albania                                                   100.0
# Algeria                                                   200.0
# American Samoa                                              NaN
# Andorra                                                     NaN
# ...                                                         ...
# Virgin Islands (U.S.)                                       NaN
# West Bank and Gaza                                          NaN
# Yemen, Rep.                                               500.0
# Zambia                                                  17000.0
# Zimbabwe                                                23000.0
#
# Metrics                ARI treatment (% of children under 5 taken to a health provider)  \
# Country_Name
# Afghanistan                                                          NaN
# ...

# %%
healthData[healthData['Country_Name'] == 'China']
# Out:
#                                                  Metrics       Metrics_Code  \
# 41     Adolescent fertility rate (births per 1,000 wo...        SP.ADO.TFRT
# 258    Adults (ages 15+) and children (0-14 years) li...        SH.HIV.TOTL
# 475    Adults (ages 15+) and children (ages 0-14) new...     SH.HIV.INCD.TL
# 692                    Adults (ages 15+) living with HIV        SH.DYN.AIDS
# 909          Adults (ages 15-49) newly infected with HIV        SH.HIV.INCD
# ...                                                  ...                ...
# 90530           Wanted fertility rate (births per woman)        SP.DYN.WFRT
# 90747  Women who were first married by age 15 (% of w...  SP.M15.2024.FE.ZS
# 90964  Women who were first married by age 18 (% of w...  SP.M18.2024.FE.ZS
# 91181  Women's share of population ages 15+ living wi...  SH.DYN.AIDS.FE.ZS
# 91398  Young people (ages 15-24) newly infected with HIV     SH.HIV.INCD.YG
#
# ...

# %%
df_pivot['2020']
# Out:
# Metrics                ARI treatment (% of children under 5 taken to a health provider)  \
# Country_Name
# Afghanistan                                                          NaN
# Albania                                                              NaN
# Algeria                                                              NaN
# American Samoa                                                       NaN
# Andorra                                                              NaN
# ...                                                                  ...
# Virgin Islands (U.S.)                                                NaN
# West Bank and Gaza                                                   NaN
# Yemen, Rep.                                                          NaN
# Zambia                                                               NaN
# Zimbabwe                                                             NaN
#
# ...
